# %%
import pandas as pd

# %%
Nutrition = pd.read_csv('Nutritional Data for Fast Foods.csv')
Nutrition.head()
# Out:
#    Unnamed: 0 Fast Food Restaurant                         Item    Type  \
# 0           0           McDonald's                    Hamburger  Burger
# 1           1           McDonald's                 Cheeseburger  Burger
# 2           2           McDonald's                            ?  Burger
# 3           3           McDonald's  Quarter Pounder with Cheese  Burger
# 4           4           McDonald's       Bacon Clubhouse Burger  Burger
#
#    Serving Size (g)  Calories  Total Fat (g)  Saturated Fat (g)  \
# 0                98       240            8.0                3.0
# 1               113       290           11.0                5.0
# 2               211       530           27.0               10.0
# 3               202       520           26.0               12.0
# 4               270       720           40.0               15.0
#
#    Trans Fat (g)  Sodium (mg)  Carbs (g)  Sugars (g)  Protein (g)
# 0            0.0        480.0       32.0         6.0         12.0
# ...

# %%
Nutrition
# Out:
#      Unnamed: 0 Fast Food Restaurant  \
# 0             0           McDonald's
# 1             1           McDonald's
# 2             2           McDonald's
# 3             3           McDonald's
# 4             4           McDonald's
# 5             5           McDonald's
# 6             6           McDonald's
# 7             7           McDonald's
# 8             8           McDonald's
# 9             9           McDonald's
# 10           10           McDonald's
# 11           11          Burger King
# 12           12          Burger King
# 13           13          Burger King
# 14           14          Burger King
# 15           15          Burger King
# 16           16          Burger King
# 17           17          Burger King
# 18           18          Burger King
# 19           19          Burger King
# 20           20          Burger King
# 21           21          Burger King
# 22           22              Wendy's
# 23           23              Wendy's
# ...

# %%
Student = pd.read_csv('student-mat.csv')
Student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
Student.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
Student['grade'].count()
# Out:
# 395

# %%
only_Female = Student.where(Student['sex'] == 'F')
only_Female.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A   4.0   4.0  at_home   teacher
# 1     GP   F  17.0       U     GT3       T   1.0   1.0  at_home     other
# 2     GP   F  15.0       U     LE3       T   1.0   1.0  at_home     other
# 3     GP   F  15.0       U     GT3       T   4.0   2.0   health  services
# 4     GP   F  16.0       U     GT3       T   3.0   3.0    other     other
#
#    ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 0  ...       no       no     4.0       3.0    4.0  1.0  1.0    3.0      6.0
# 1  ...      yes       no     5.0       3.0    3.0  1.0  1.0    3.0      4.0
# 2  ...      yes       no     4.0       3.0    2.0  2.0  3.0    3.0     10.0
# 3  ...      yes      yes     3.0       2.0    2.0  1.0  1.0    5.0      2.0
# 4  ...       no       no     4.0       3.0    2.0  1.0  2.0    5.0      4.0
#
#   grade
# 0     F
# 1     F
# 2     C
# 3     B
# 4     C
#
# ...

# %%
only_Female = only_Female.dropna()
only_Female
# Out:
#     school sex   age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  18.0       U     GT3       A   4.0   4.0   at_home   teacher
# 1       GP   F  17.0       U     GT3       T   1.0   1.0   at_home     other
# 2       GP   F  15.0       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F  15.0       U     GT3       T   4.0   2.0    health  services
# 4       GP   F  16.0       U     GT3       T   3.0   3.0     other     other
# 7       GP   F  17.0       U     GT3       A   4.0   4.0     other   teacher
# 10      GP   F  15.0       U     GT3       T   4.0   4.0   teacher    health
# 11      GP   F  15.0       U     GT3       T   2.0   1.0  services     other
# 15      GP   F  16.0       U     GT3       T   4.0   4.0    health     other
# 16      GP   F  16.0       U     GT3       T   4.0   4.0  services  services
# 17      GP   F  16.0       U     GT3       T   3.0   3.0     other     other
# ...

# %%
Student['grade'] == 'A'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 365    False
# 366    False
# 367    False
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374     True
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391     True
# 392    False
# 393    False
# 394    False
# Name: grade, Length: 395, dtype: bool

# %%
Student['grade'].value_counts()
# Out:
# C    170
# B    103
# F     69
# A     53
# Name: grade, dtype: int64

# %%
53/69
# Out:
# 0.7681159420289855

# %%
# Out:
# C    1.0
# B    1.0
# F    1.0
# A    1.0
# Name: grade, dtype: float64

# %%
Student.grade.value_counts()['A']/Student.grade.value_counts()['F']
# Out:
# 0.7681159420289855

# %%
Only_Female = Student[Student.sex == 'F']
Only_Female
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# ...

# %%
Only_Female.grade.value_counts()['A']+Only_Female.grade.value_counts()['B']
# Out:
# 74

# %%
Only_Fem = Only_Feamale.grade = 1 where Only_Feamale.grade == 'A'
# Out:
#   File "<ipython-input-79-80d847109eeb>", line 1
#     Only_Fem = Only_Feamale.grade = 1 where Only_Feamale.grade == 'A'
#                                           ^
# SyntaxError: invalid syntax

# %%
cnt = 0 
final = 0
for i in Only_Female['grade']:
    if i == 'A':
        cnt = 4
    if i == 'B':
        cnt = 3
    if i == 'C':
        cnt = 2
    if i == 'F':
        cnt = 1 
        
    final = final + cnt
    
        
print(final/Only_Female.count())
# Out:
# school        2.274038
# sex           2.274038
# age           2.274038
# address       2.274038
# famsize       2.274038
# Pstatus       2.274038
# Medu          2.274038
# Fedu          2.274038
# Mjob          2.274038
# Fjob          2.274038
# reason        2.274038
# guardian      2.274038
# traveltime    2.274038
# studytime     2.274038
# failures      2.274038
# schoolsup     2.274038
# famsup        2.274038
# paid          2.274038
# activities    2.274038
# nursery       2.274038
# higher        2.274038
# internet      2.274038
# romantic      2.274038
# famrel        2.274038
# freetime      2.274038
# goout         2.274038
# Dalc          2.274038
# Walc          2.274038
# health        2.274038
# absences      2.274038
# grade         2.274038
# dtype: float64

# %%
Nutrition = pd.read_csv('Nutritional Data for Fast Foods.csv')
Nutrition
# Out:
#      Unnamed: 0 Fast Food Restaurant  \
# 0             0           McDonald's
# 1             1           McDonald's
# 2             2           McDonald's
# 3             3           McDonald's
# 4             4           McDonald's
# 5             5           McDonald's
# 6             6           McDonald's
# 7             7           McDonald's
# 8             8           McDonald's
# 9             9           McDonald's
# 10           10           McDonald's
# 11           11          Burger King
# 12           12          Burger King
# 13           13          Burger King
# 14           14          Burger King
# 15           15          Burger King
# 16           16          Burger King
# 17           17          Burger King
# 18           18          Burger King
# 19           19          Burger King
# 20           20          Burger King
# 21           21          Burger King
# 22           22              Wendy's
# 23           23              Wendy's
# ...

# %%
np.isnan(np.nan)
# Out:
# True

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
Nutrition.isnull().any()
# Out:
# Unnamed: 0              False
# Fast Food Restaurant    False
# Item                    False
# Type                    False
# Serving Size (g)        False
# Calories                False
# Total Fat (g)            True
# Saturated Fat (g)       False
# Trans Fat (g)            True
# Sodium (mg)              True
# Carbs (g)               False
# Sugars (g)              False
# Protein (g)              True
# dtype: bool

# %%
Unique = Nutrition.Item.unique()
Unique.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-3ae2002aaddb> in <module>
#       1 Unique = Nutrition.Item.unique()
# ----> 2 Unique.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
Nutrition.Item.nunique()
# Out:
# 101

# %%
Nutrition.Type.nunique()
# Out:
# 6

# %%
Nutrition.groupby(['Type']).mean()
# Out:
#                           Unnamed: 0  Serving Size (g)    Calories  \
# Type
# Breaded Chicken Sandwich   60.454545        215.727273  522.090909
# Burger                     61.391304        241.797101  620.202899
# Chicken Nuggets            62.272727        100.545455  274.545455
# French Fries               68.333333        109.500000  314.083333
# Grilled Chicken Sandwich   61.090909        216.090909  408.000000
# Milkshake                  66.416667        367.000000  606.666667
#
#                           Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# Type
# Breaded Chicken Sandwich      26.018182           4.563636       0.010000
# Burger                        35.670769          13.563768       1.377419
# Chicken Nuggets               17.372727           3.054545       0.010000
# French Fries                  15.308333           2.891667       0.100000
# Grilled Chicken Sandwich      17.000000           3.863636       0.040000
# ...

# %%
Nutrition.groupby(['Protein (g)']).max()
# Out:
#              Unnamed: 0 Fast Food Restaurant  \
# Protein (g)
# 2.0                  10           McDonald's
# 3.0                 119         White Castle
# 3.4                  86           Carl's Jr.
# 4.0                  73              Wendy's
# 7.0                 124         White Castle
# 8.0                 120         White Castle
# 9.0                  50              Wendy's
# 10.0                125         White Castle
# 11.0                101         White Castle
# 12.0                108         White Castle
# 13.0                 69      Jack in the Box
# 14.0                109          Whataburger
# 15.0                105         White Castle
# 16.0                121              Wendy's
# 17.0                118          Whataburger
# 17.7                 74           Carl's Jr.
# 18.0                106         White Castle
# 19.0                 53                Sonic
# 20.5                 75           Carl's Jr.
# ...
